# %%
import seaborn as sns
import pandas as pd
from sklearn.metrics import pairwise_distances 
# %matplotlib inline

# %%
import numpy as np
threshold_troppo = pd.read_csv(
    '../datasets/Desai-GTEx_ensembl.csv',
    index_col=0)

thresholded_genes = pd.DataFrame(data=np.where(threshold_troppo > 0, 1, 0),
                                          index=threshold_troppo.index,
                                          columns=threshold_troppo.columns)

thresholded_genes
# Out:
#                    ENSG00000000419  ENSG00000000460  ENSG00000000938  \
# ensembl_gene_id
# Lung_Healthy                     1                1                1
# Lung_COVID19                     1                1                1
# Heart_Healthy                    1                1                1
# Heart_COVID19                    1                0                1
# Liver_Healthy                    1                1                1
# Liver_COVID19                    0                1                1
# Kidney_Healthy                   1                1                1
# Kidney_COVID19                   0                0                1
# Intestine_Healthy                1                1                1
# Intestine_COVID19                1                1                1
#
#                    ENSG00000000971  ENSG00000001036  ENSG00000001084  \
# ensembl_gene_id
# Lung_Healthy                     1                1                1
# Lung_COVID19                     1                1                1
# Heart_Healthy                    1                1                1
# Heart_COVID19                    1                1                1
# Liver_Healthy                    1                1                1
# Liver_COVID19                    1                1                1
# Kidney_Healthy                   1                1                1
# Kidney_COVID19                   1                1                1
# Intestine_Healthy                1                1                1
# Intestine_COVID19                1                1                1
#
#                    ENSG00000001167  ENSG00000001461  ENSG00000001497  \
# ensembl_gene_id
# Lung_Healthy                     1                1                1
# Lung_COVID19                     1                1                1
# Heart_Healthy                    1                1                1
# Heart_COVID19                    1                1                1
# Liver_Healthy                    1                1                1
# Liver_COVID19                    1                1                1
# Kidney_Healthy                   1                1                1
# Kidney_COVID19                   1                1                1
# Intestine_Healthy                1                1                1
# Intestine_COVID19                1                1                1
#
#                    ENSG00000001561  ...  ENSG00000271321  ENSG00000271605  \
# ensembl_gene_id                     ...
# Lung_Healthy                     1  ...                1                1
# Lung_COVID19                     1  ...                0                1
# Heart_Healthy                    1  ...                0                1
# Heart_COVID19                    1  ...                0                1
# Liver_Healthy                    1  ...                0                1
# Liver_COVID19                    1  ...                0                0
# Kidney_Healthy                   1  ...                0                1
# Kidney_COVID19                   1  ...                0                1
# Intestine_Healthy                1  ...                0                1
# Intestine_COVID19                1  ...                0                1
#
#                    ENSG00000272047  ENSG00000272325  ENSG00000272333  \
# ensembl_gene_id
# Lung_Healthy                     1                1                1
# Lung_COVID19                     1                1                1
# Heart_Healthy                    1                1                1
# Heart_COVID19                    1                1                1
# Liver_Healthy                    1                1                1
# Liver_COVID19                    1                1                1
# Kidney_Healthy                   1                1                1
# Kidney_COVID19                   1                1                1
# Intestine_Healthy                1                1                1
# Intestine_COVID19                1                1                1
#
#                    ENSG00000272414  ENSG00000272573  ENSG00000272968  \
# ensembl_gene_id
# Lung_Healthy                     1                1                1
# Lung_COVID19                     1                0                0
# Heart_Healthy                    1                1                0
# Heart_COVID19                    1                0                0
# Liver_Healthy                    1                1                1
# Liver_COVID19                    1                0                0
# Kidney_Healthy                   1                1                1
# Kidney_COVID19                   1                0                0
# Intestine_Healthy                1                1                1
# Intestine_COVID19                1                0                0
#
#                    ENSG00000273045  ENSG00000273079
# ensembl_gene_id
# Lung_Healthy                     1                0
# Lung_COVID19                     0                1
# Heart_Healthy                    1                0
# Heart_COVID19                    0                1
# Liver_Healthy                    1                0
# Liver_COVID19                    0                1
# Kidney_Healthy                   1                0
# Kidney_COVID19                   1                0
# Intestine_Healthy                1                0
# Intestine_COVID19                0                1
#
# [10 rows x 12870 columns]

# %%
dff = pd.DataFrame(data=1-pairwise_distances(thresholded_genes.to_numpy(), metric='jaccard'),
                   index=threshold_troppo.index,
                   columns=threshold_troppo.index)

dff
# Out:
# C:\Users\biosy\anaconda3\envs\TS_Rec_Pipeline\lib\site-packages\sklearn\metrics\pairwise.py:2025: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# ensembl_gene_id    Lung_Healthy  Lung_COVID19  Heart_Healthy  Heart_COVID19  \
# ensembl_gene_id
# Lung_Healthy           1.000000      0.851263       0.902854       0.728625
# Lung_COVID19           0.851263      1.000000       0.852359       0.820432
# Heart_Healthy          0.902854      0.852359       1.000000       0.777952
# Heart_COVID19          0.728625      0.820432       0.777952       1.000000
# Liver_Healthy          0.875250      0.837249       0.885161       0.759499
# Liver_COVID19          0.728364      0.794703       0.741914       0.776004
# Kidney_Healthy         0.926293      0.846004       0.909854       0.739330
# Kidney_COVID19         0.703074      0.774157       0.719576       0.767603
# Intestine_Healthy      0.932820      0.835916       0.902373       0.729044
# Intestine_COVID19      0.842356      0.886634       0.857785       0.799513
#
# ensembl_gene_id    Liver_Healthy  Liver_COVID19  Kidney_Healthy  \
# ensembl_gene_id
# Lung_Healthy            0.875250       0.728364        0.926293
# Lung_COVID19            0.837249       0.794703        0.846004
# Heart_Healthy           0.885161       0.741914        0.909854
# Heart_COVID19           0.759499       0.776004        0.739330
# Liver_Healthy           1.000000       0.762913        0.894776
# Liver_COVID19           0.762913       1.000000        0.737277
# Kidney_Healthy          0.894776       0.737277        1.000000
# Kidney_COVID19          0.712120       0.747065        0.717082
# Intestine_Healthy       0.875444       0.730495        0.925302
# Intestine_COVID19       0.823513       0.778040        0.846672
#
# ensembl_gene_id    Kidney_COVID19  Intestine_Healthy  Intestine_COVID19
# ensembl_gene_id
# Lung_Healthy             0.703074           0.932820           0.842356
# Lung_COVID19             0.774157           0.835916           0.886634
# Heart_Healthy            0.719576           0.902373           0.857785
# Heart_COVID19            0.767603           0.729044           0.799513
# Liver_Healthy            0.712120           0.875444           0.823513
# Liver_COVID19            0.747065           0.730495           0.778040
# Kidney_Healthy           0.717082           0.925302           0.846672
# Kidney_COVID19           1.000000           0.703466           0.755219
# Intestine_Healthy        0.703466           1.000000           0.857208
# Intestine_COVID19        0.755219           0.857208           1.000000

# %%
dff.shape
# Out:
# (10, 10)

# %%
# calculate the distance based on jaccard similarity and subtract 1
# because a value of 1 in original means no similarity

# display as a heatmap
sns.heatmap(dff, annot=True)
# Out:
# <AxesSubplot:xlabel='ensembl_gene_id', ylabel='ensembl_gene_id'>

# %%
thresholded_genes.to_csv('HumanGEM_Desai-GTEx_fastcore_local2_1_3_2.csv')
