# %%
import seaborn as sns
import pandas as pd
from sklearn.metrics import pairwise_distances 
# %matplotlib inline

# %%
threshold_troppo = pd.read_csv(
    'Threshold_matrix_HumanGEM_Desai-GTEx_local2_3_1_2.csv',
    index_col=0)
dff = pd.DataFrame(data=1-pairwise_distances(threshold_troppo.to_numpy(), metric='jaccard'),
                   index=threshold_troppo.index,
                   columns=threshold_troppo.index)

dff
# Out:
# C:\Users\biosy\anaconda3\envs\troppo-dev\lib\site-packages\sklearn\metrics\pairwise.py:1875: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
#                                 Lung_Healthy_local2_1_3_2  \
# Lung_Healthy_local2_1_3_2                        1.000000
# Lung_COVID19_local2_1_3_2                        0.765978
# Heart_Healthy_local2_1_3_2                       0.633828
# Heart_COVID19_local2_1_3_2                       0.611717
# Liver_Healthy_local2_1_3_2                       0.520380
# Liver_COVID19_local2_1_3_2                       0.433475
# Kidney_Healthy_local2_1_3_2                      0.699413
# Kidney_COVID19_local2_1_3_2                      0.438684
# Intestine_Healthy_local2_1_3_2                   0.796251
# Intestine_COVID19_local2_1_3_2                   0.693243
#
#                                 Lung_COVID19_local2_1_3_2  \
# Lung_Healthy_local2_1_3_2                        0.765978
# Lung_COVID19_local2_1_3_2                        1.000000
# Heart_Healthy_local2_1_3_2                       0.548263
# Heart_COVID19_local2_1_3_2                       0.651032
# Liver_Healthy_local2_1_3_2                       0.445503
# Liver_COVID19_local2_1_3_2                       0.441894
# Kidney_Healthy_local2_1_3_2                      0.587530
# Kidney_COVID19_local2_1_3_2                      0.453120
# Intestine_Healthy_local2_1_3_2                   0.679821
# Intestine_COVID19_local2_1_3_2                   0.803752
#
#                                 Heart_Healthy_local2_1_3_2  \
# Lung_Healthy_local2_1_3_2                         0.633828
# Lung_COVID19_local2_1_3_2                         0.548263
# Heart_Healthy_local2_1_3_2                        1.000000
# Heart_COVID19_local2_1_3_2                        0.640497
# Liver_Healthy_local2_1_3_2                        0.594675
# Liver_COVID19_local2_1_3_2                        0.446025
# Kidney_Healthy_local2_1_3_2                       0.692937
# Kidney_COVID19_local2_1_3_2                       0.445919
# Intestine_Healthy_local2_1_3_2                    0.638672
# Intestine_COVID19_local2_1_3_2                    0.569633
#
#                                 Heart_COVID19_local2_1_3_2  \
# Lung_Healthy_local2_1_3_2                         0.611717
# Lung_COVID19_local2_1_3_2                         0.651032
# Heart_Healthy_local2_1_3_2                        0.640497
# Heart_COVID19_local2_1_3_2                        1.000000
# Liver_Healthy_local2_1_3_2                        0.468217
# Liver_COVID19_local2_1_3_2                        0.510295
# Kidney_Healthy_local2_1_3_2                       0.562382
# Kidney_COVID19_local2_1_3_2                       0.520104
# Intestine_Healthy_local2_1_3_2                    0.584796
# Intestine_COVID19_local2_1_3_2                    0.661532
#
#                                 Liver_Healthy_local2_1_3_2  \
# Lung_Healthy_local2_1_3_2                         0.520380
# Lung_COVID19_local2_1_3_2                         0.445503
# Heart_Healthy_local2_1_3_2                        0.594675
# Heart_COVID19_local2_1_3_2                        0.468217
# Liver_Healthy_local2_1_3_2                        1.000000
# Liver_COVID19_local2_1_3_2                        0.513430
# Kidney_Healthy_local2_1_3_2                       0.635191
# Kidney_COVID19_local2_1_3_2                       0.375445
# Intestine_Healthy_local2_1_3_2                    0.551105
# Intestine_COVID19_local2_1_3_2                    0.446785
#
#                                 Liver_COVID19_local2_1_3_2  \
# Lung_Healthy_local2_1_3_2                         0.433475
# Lung_COVID19_local2_1_3_2                         0.441894
# Heart_Healthy_local2_1_3_2                        0.446025
# Heart_COVID19_local2_1_3_2                        0.510295
# Liver_Healthy_local2_1_3_2                        0.513430
# Liver_COVID19_local2_1_3_2                        1.000000
# Kidney_Healthy_local2_1_3_2                       0.450957
# Kidney_COVID19_local2_1_3_2                       0.493660
# Intestine_Healthy_local2_1_3_2                    0.439514
# Intestine_COVID19_local2_1_3_2                    0.437536
#
#                                 Kidney_Healthy_local2_1_3_2  \
# Lung_Healthy_local2_1_3_2                          0.699413
# Lung_COVID19_local2_1_3_2                          0.587530
# Heart_Healthy_local2_1_3_2                         0.692937
# Heart_COVID19_local2_1_3_2                         0.562382
# Liver_Healthy_local2_1_3_2                         0.635191
# Liver_COVID19_local2_1_3_2                         0.450957
# Kidney_Healthy_local2_1_3_2                        1.000000
# Kidney_COVID19_local2_1_3_2                        0.454064
# Intestine_Healthy_local2_1_3_2                     0.720806
# Intestine_COVID19_local2_1_3_2                     0.580772
#
#                                 Kidney_COVID19_local2_1_3_2  \
# Lung_Healthy_local2_1_3_2                          0.438684
# Lung_COVID19_local2_1_3_2                          0.453120
# Heart_Healthy_local2_1_3_2                         0.445919
# Heart_COVID19_local2_1_3_2                         0.520104
# Liver_Healthy_local2_1_3_2                         0.375445
# Liver_COVID19_local2_1_3_2                         0.493660
# Kidney_Healthy_local2_1_3_2                        0.454064
# Kidney_COVID19_local2_1_3_2                        1.000000
# Intestine_Healthy_local2_1_3_2                     0.432278
# Intestine_COVID19_local2_1_3_2                     0.451173
#
#                                 Intestine_Healthy_local2_1_3_2  \
# Lung_Healthy_local2_1_3_2                             0.796251
# Lung_COVID19_local2_1_3_2                             0.679821
# Heart_Healthy_local2_1_3_2                            0.638672
# Heart_COVID19_local2_1_3_2                            0.584796
# Liver_Healthy_local2_1_3_2                            0.551105
# Liver_COVID19_local2_1_3_2                            0.439514
# Kidney_Healthy_local2_1_3_2                           0.720806
# Kidney_COVID19_local2_1_3_2                           0.432278
# Intestine_Healthy_local2_1_3_2                        1.000000
# Intestine_COVID19_local2_1_3_2                        0.663162
#
#                                 Intestine_COVID19_local2_1_3_2
# Lung_Healthy_local2_1_3_2                             0.693243
# Lung_COVID19_local2_1_3_2                             0.803752
# Heart_Healthy_local2_1_3_2                            0.569633
# Heart_COVID19_local2_1_3_2                            0.661532
# Liver_Healthy_local2_1_3_2                            0.446785
# Liver_COVID19_local2_1_3_2                            0.437536
# Kidney_Healthy_local2_1_3_2                           0.580772
# Kidney_COVID19_local2_1_3_2                           0.451173
# Intestine_Healthy_local2_1_3_2                        0.663162
# Intestine_COVID19_local2_1_3_2                        1.000000

# %%
dff.shape
# Out:
# (10, 10)

# %%
# calculate the distance based on jaccard similarity and subtract 1
# beacause a value of 1 in original means no similarity

# display as a heatmap
sns.heatmap(dff, annot=True)
